# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

driver = webdriver.Edge()

driver.get('https://quotes.toscrape.com/js/')

# <small class="author">Albert Einstein</small>

# element = driver.find_element(by= By.CLASS_NAME, value="author")
# print(element.text)

elements = driver.find_elements(by= By.CLASS_NAME, value="author")
for element in elements:
    print(element.text)

driver.quit()
# Out:
# Albert Einstein
# J.K. Rowling
# Albert Einstein
# Jane Austen
# Marilyn Monroe
# Albert Einstein
# André Gide
# Thomas A. Edison
# Eleanor Roosevelt
# Steve Martin

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

driver = webdriver.Edge()

driver.get('https://subway.com.my/find-a-subway')


elements = driver.find_elements(by= By.CLASS_NAME, value="fp_listitem fp_list_")
for element in elements:
    print(element.text)

driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

LOCATION = "kuala lumpur"
URL = "https://subway.com.my/find-a-subway"


driver = webdriver.Edge()
driver.get(URL)

# sleep to let pages load
time.sleep(2)

try:
    filter = driver.find_element(By.XPATH, value="/html/body/div[2]/div[2]/div/div/div[2]/div/div/div/div/div/div[1]/div[2]/div[2]/form/div[1]/input")
    filter.send_keys(LOCATION)
    filter.send_keys(Keys.ENTER)

    elements = driver.find_elements(by= By.CSS_SELECTOR, value="div[class^='fp_listitem fp_list_marker']:not([style*='display: none'])")
    for element in elements:
        print(element.text)

finally:
    driver.quit()
# Out:
# Subway Menara UOA Bangsar
# Jalan Bangsar Utama 1, Unit 1-2-G, Menara UOA Bangsar, Kuala Lumpur, 59000
# Monday - Sunday, 8:00 AM - 8:00 PM
# Subway One Utama
# 318A One Utama, Lower Ground Floor, New Wing, 1 Utama Shopping Centre, Petaling Jaya, 47800
# 0800 - 2200 (Sun - Thur)
# 0800 - 2230 (Fri & Sat)
# Subway Jln Pinang
# G9, Wisma UOA II, 19, Jalan Pinang, Kuala Lumpur, 50450
# Monday - Saturday, 8:00 AM – 9:00PM
# Sunday, 11:30 AM – 6:30PM
# Subway UOA Damansara
# Unit 50-G-5, Ground Floor, Wisma UOA Damansara, No. 50, Jalan Dungun, Kuala Lumpur, 50490
# Monday - Saturday, 8:00 AM – 8:30PM
# Sunday, Closed
# Subway The Mines
# Lot L1-93, Level 1, Mines Shopping Fair,Jln Dulang, Mines Resort City, Seri Kembangan, 43300
# Monday - Sunday, 10:00 AM - 10:00 PM
# Subway Mont Kiara
# E-01-16 ,Block E, Plaza Mont Kiara, 2 Jalan Kiara, Mont Kiara, Kuala Lumpur, 50480
# Monday - Sunday, 10:00 AM - 10:00 PM
# Subway Amcorp Mall
# (Canopy Area), Lot KG-05, 18 Jln Persiaran, Ground Floor, Barat, Petaling Jaya, 46050
# Monday - Friday, 9:00 AM – 10:00PM
# Saturday & Sunday, 10:00 AM – 10:00PM
# Subway Avenue K
# Lot UC-8 & 9, Upper Concourse Level, Avenue K, No. 156, Jalan Ampang, Kuala Lumpur, 50450
# Monday - Sunday, 8:00 AM - 10:00 PM
# Subway Center Point
# Lebuh Bandar Utama, Center Point, Lot G104B Gr Floor, Petaling Jaya, 47800
# Monday, 8:00 AM – 10:00PM
# Tuesday - Wednesday, 8:00 AM – 10:30PM
# Thursday, 8:00 AM – 9:00PM
# Friday & Saturday, 8:00 AM – 11:00PM
# Sunday, 8:00 AM – 10:30PM
# Subway Shell Sunway Mentari
# 1, Jalan PJS 8/9 (Shell) Bandar Sunway, 46000 Selangor
# Monday - Sunday (08:00AM - 10:00PM)
# Subway Berjaya Times Square
# LG-08A, Berjaya Times Square, No. 1, Jalan Imbi, Kuala Lumpur, 55100
# Monday - Sunday, 10:00 AM - 10:00 PM
# Subway
# Lot 1-03, Level 1, Residensi UTMKL, No 8 Jalan Maktab, 54000 Kuala Lumpur
# Tuesday – Sunday, 10:00 AM – 9:30PM
# Monday, 8:00 AM – 9:30PM
# Subway KLTS
# 45-G, Plaza KLTS, Block C, Jalan Gombak, 53000 Kuala Lumpur
# Monday - Sunday, 9:00 AM - 9:30 PM
# Subway Jaya One
# 100-P2.015, Level 2, Block J, The School Jaya One, No.72A Jalan Prof Diraja Ungku Aziz, 46200 Petaling Jaya, Selangor
# Monday - Sunday, 10:30 AM - 9:00 PM
# Subway Petronas Grand Saga 3
# Lot 432, Lebuhraya Grand Saga, (Kajang Bound) 43300, Kajang, Selangor
# Subway MSU
# Lot S0205 Management & Science University, Seksyen 13, 40100 Shah Alam, Selangor
# Monday - Sunday, 8:00 AM – 8:00PM
#
# Subway Sungai Buloh
# 2390, Jalan 1A-1, Bdr Baru Sg Buloh, Seksyen U20, 40610 Shah Alam, Selangor
# Monday - Sunday, 8:00 AM - 10:00 PM
# Subway Subang Parade
# LGC17, Lower Ground Floor, Subang Parade Shopping Centre, Jalan Kemajuan Subang, Ss 16, 47500 Subang Jaya, Selangor
# Monday - Sunday, 9:00 AM - 10:00 PM
#
#
# Subway KL East Mall
# LG 37 , Lower Ground Floor, KL East Mall, 823 Jalan Lingkaran Tengah 2, KL Timur, 53100 Kuala Lumpur
# Sunday – Thursday, 10:00 AM – 8:00PM
# Friday & Saturday, 9:00 AM – 8:00PM
# Subway Bandar Sri Permaisuri
# Lot R-G-07, Ground Floor Q Avenue, Kompleks Permaisuri Q, No.6,Jalan Sri Permaisuri, Bandar Sri Permaisuri, Cheras 56000 Kuala Lumpur
# Monday - Sunday, 10:00 AM - 9:00 PM
#
# Subway Mahkota Cheras
# 32G, Jalan Temenggung 1/9, Bandar Mahkota Cheras, 43200 Cheras, Selangor
# Monday - Sunday, 10:00 AM - 11:00 PM
#
# Subway KLCC
# Lot F208, Second Floor, Suria KLCC, Jalan Ampang, Golden, 50088 Kuala Lumpur
# Monday - Sunday, 10:00 AM - 10:00 PM
#
#
#
# Subway Sri Serdang
# No 11 Jalan 18/34 Taman Sri Serdang, Seri Kembangan 43300 Selangor
# Monday - Sunday, 8:00 AM - 10:00 PM
#
# Subway Kepong
# 91, Jalan Metro Barat Perdana 1, Taman Usahawan Kepong, 52100 Kuala Lumpur
# Monday - Sunday, 8:00 AM - 8:30 PM
# Subway Damansara Damai
# G001, Seasons Square, Jalan Pju 10/3C, Damansara Damai, 47830 Petaling Jaya, Selangor
# Monday - Sunday, 7:30 AM - 10:00 PM
#
# Subway Kidzania KL
# Kidzania Kuala Lumpur, Lot 11, Lower Ground Curve NX, No.18 Jalan PJU 7/5, 47810 Mutiara Damansara, Petaling Jaya Selangor
# Mon - Sun : 10am-6pm
# Tues : Close
#
# Subway BTHO
# No 5A, Ground Floor, Jalan Suarasa 8/3 Bandar Tun Hussien Onn, 43200 Cheras, Selangor Darul Ehsan
# Monday - Sunday, 7:30 AM - 10:00 PM
# Subway Thomson Hospital
# GF-Unit 1109-3, 11 Jalan Teknologi PJU 5, 47810 Kota Damansara, Petaling Jaya, Selangor
# Monday - Friday, 8:00 AM – 9:00PM
# Saturday & Sunday, 9:00 AM – 7:00PM
# Subway BHP Jalan Kuching
# BHPetrol Jalan Kuching, Lot PT 4283 & Lot 6086 Jalan Kuching, 52100 Kuala Lumpur.
# Monday - Sunday, 7:30 AM - 10:00 PM
# Subway Hero Puchong
# Lot No G-13 , Hero Puchong, Lot 1, Jalan Puteri 1/1 , 43200 Puchong, Selangor.
# Monday - Sunday, 9:00 AM - 9:00 PM
#
#
#
# Subway Pavilion Bukit Jalil
# Lot 1.40.00, Persiaran Jalil Utama, Bukit Jalil, Kuala Lumpur
# Monday - Sunday, 9:30 AM - 10:00 PM
#
#
#
#
# Subway Petron Ukay Perdana
# No. PT 5765, Jln Ukay Perdana, Ukay Perdana, 68000 Ampang, Selangor
# Monday - Sunday (8:00AM - 10:00PM)
#
#
# Subway Lotus Cheras
# Lot G27-G29, No.2, Jalan Midah 2, Taman Midah, 56000 Cheras, Kuala Lumpur
# Monday - Sunday, 9:30 AM - 9:00 PM
# Subway Equine Park
# 7-G, Jalan Putra Permai 1A, Taman Equine, 43300 Seri Kembangan, Selangor.
# Monday - Sunday, 8:00 AM - 10:00 PM
#
# Subway Syopz
# G-5, The Boardwalk, No.2, Jalan Taylor’s, 47500 Subang Jaya, Selangor Darul Ehsan
# Monday - Saturday, 10:00 AM – 10:00PM
# Sunday, Closed
#
# Subway Matahari Mall
# Lot S15 & S16 , Ground Floor, Matahari Mall, No. 1, PJS 2/18, Taman Maju Jaya, 46000 Petaling Jaya,Selangor
# Monday - Sunday (10:00AM - 9:30PM)
# Fasting Month :
# Mon-Sun, 12:00PM - 09:00PM
# Subway SPARK
# 1-01 Plaza Salak Park, No 2, Jalan 1/125E, Taman Desa Petaling, 57100 Kuala Lumpur
# Monday - Sunday (8:00AM - 10:00PM)
#
# Subway Sunway Pyramid
# LG2.32, Lower Ground Two, Sunway Pyramid, 3, Jalan PJS 11/15, Bandar Sunway, 47500 Petaling Jaya, Selangor
# Monday - Sunday, 10:00 AM - 10:00 PM
# Subway Caltex Serdang
# No.2, Lot.14985, Jalan SR 8/1, Taman Putra Indah, 43300, Seri Kembangan, Selangor
# Monday - Sunday, 8:00 AM - 10:00 PM
# Subway Subang Bestari
# No 4, Jalan Nova N U5/N, Seksyen U5, 40150 Shah Alam, Selangor
# Monday - Sunday, 10:00 AM - 10:00 PM
# Subway Denai Alam
# Unit Ground Floor, No 7, Jalan Electron E U16/E, Seksyen U16, 40160 Shah Alam,Selangor
# Monday - Sunday, 8:15 AM - 9:45 PM
# Subway Aeon Taman Maluri
# Lot G32,AEON Mall Taman Maluri, Jalan Jejaka, Taman Maluri Cheras 55100, Kuala Lumpur
# Sunday - Thursday, 10:00 AM – 10:00PM
# Friday & Saturday, 10:00 AM – 10:30PM
#
# Subway Subang Perdana
# No. 17-G, Jalan Dinar D U3/D, Seksyen U3, 40150 Shah Alam, Selangor
# Monday - Sunday, 8:00 AM - 10:00 PM
# Fasting Month :
# Mon - Sun, 10:00AM - 10:00PM
# Subway KL Gateway
# G1.K5, Lower Ground 1, KL Gateway Mall, 2, Jalan Kerinchi, 59200 Kuala Lumpur
# Monday - Sunday (8:00AM - 10:00PM)
# Subway Lotuss Selayang
# Lot F-18 & 18 (External) No. 1081, Jalan Ipoh Mukim Batu 51200 Kuala Lumpur
# Monday - Sunday (10:00AM - 10:00PM)
#
# Subway Hartamas SC
# Lot G-22A & G-22B . Hartamas Shopping Center, 60, Jalan Sri Hartamas 1, Taman Sri Hartamas, 50480 Kuala Lumpur, Wilayah Persekutuan Kuala Lumpur
# Monday - Sunday (10:00AM - 10:00PM)
# Subway Paradigm Mall
# LG-33A(P), LG Floor No. 1, Jalan SS7/26A Kelana Jaya 47301 Petaling Jaya Selangor
# Monday - Sunday, 10:00 AM - 10:00 PM
# Subway
# LOTUS’S AMPANG - OL1, Jalan Pandan Prima Dataran, Pandan Indah, 55100 Kuala Lumpur
# Monday - Sunday (10:00AM - 10:00PM)
#
#
#
# Subway Razak City
# Block B-G-19 Residensi Bandar Razak, No 01 Jln Razak Mansion, 57100 Sungai Besi, K.L
# Monday - Sunday (08:00AM to 10:00PM)
#
# Subway Aeon Cheras Selatan
# F60, First Floor, ÆON Cheras Selatan, Lebuh Utama Tun Hussein Onn, Tun Hussein Onn, Cheras, Selangor
# Monday to Sunday (10:00AM - 10:00PM)
#
#
#
#
#
#
#
# Subway Kiara Bay
# "Lot G-22, The Beat Kiara Bay Kepong Metropolitan Park,Jalan Lingkaran Tengah 52100 Kuala Lumpur."
# Monday - Sunday (10:00AM - 10:00PM)
#
# Subway Putra Ampang
# No 46-G, Jalan Bunga Tanjung 9B, Taman Putra, Ampang 68000, Selangor
# Monday - Sunday (08:00AM - 10:00PM)

# %%
import pandas as pd
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys


URL = "https://subway.com.my/find-a-subway"
LOCATION = "kuala lumpur"


driver = webdriver.Edge()
driver.get(URL)

# sleep to let pages load
time.sleep(2)

try:
    filter = driver.find_element(By.XPATH, value="/html/body/div[2]/div[2]/div/div/div[2]/div/div/div/div/div/div[1]/div[2]/div[2]/form/div[1]/input")
    filter.send_keys(LOCATION)
    filter.send_keys(Keys.ENTER)
    
    # needs to sleep, else selerium scrapes web before filtering location
    time.sleep(2)

    # elements = driver.find_elements(by= By.XPATH, value="//div[@class='fp_listitem fp_list_marker']")
    elements = driver.find_elements(by= By.CSS_SELECTOR, value="div[class^='fp_listitem fp_list_marker']:not(div[style*=' display: none;'])")
    for WebElement in elements:
        elementHTML = WebElement.get_attribute('outerHTML')
        elementSoup = BeautifulSoup(elementHTML,'html.parser')
        
        try:
            location_name = elementSoup.find("h4")
            location_address = elementSoup.select('div.infoboxcontent p')[0]
            operating_hours = elementSoup.select('div.infoboxcontent p')[2]
            waze_link = elementSoup.select('div.directionButton a')[1]['href']
            
            latitude = elementSoup.find("div")['data-latitude']
            longitude = elementSoup.find("div")['data-longitude']
            
            try:
                df = pd.DataFrame(
                    {
                        "Outlet Name": [location_name.text],
                        "Outlet Address": [location_address.text],
                        "Operation Hours": [operating_hours.text],
                        "Latitude": [latitude],
                        "Longitude": [longitude],
                        "Waze Link": [waze_link] ,
                    }
                )
                print(df.head())
            except Exception as e:
                print(f"Error {e}")
            
            
            print(f"Outlet Name: {location_name.text}")
            print(f"Outlet Address: {location_address.text}")
            print(f"Operation Hours: {operating_hours.text}")
            print(f"Latitude: {latitude}")
            print(f"Longitude: {longitude}")
            print(f"Waze Link: {waze_link}")
            
        except:
            print(elementSoup)
            
        print("\n")
        # print(elementSoup)

finally:
    driver.quit()
# Out:
#                  Outlet Name  \
# 0  Subway Menara UOA Bangsar
#
#                                       Outlet Address  \
# 0  Jalan Bangsar Utama 1, Unit 1-2-G, Menara UOA ...
#
#                       Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 8:00 AM - 8:00 PM  3.128099  101.678678
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/my...
# Outlet Name: Subway Menara UOA Bangsar
# Outlet Address: Jalan Bangsar Utama 1, Unit 1-2-G, Menara UOA Bangsar, Kuala Lumpur, 59000
# Operation Hours: Monday - Sunday, 8:00 AM - 8:00 PM
# Latitude: 3.128099
# Longitude: 101.678678
# Waze Link: https://www.waze.com/en/live-map/directions/my/federal-territory-of-kuala-lumpur/kuala-lumpur/subway-@
# Operation Hours: Monday - Sunday, 8:00 AM - 10:00 PM
# Latitude: 3.159477
# Longitude: 101.713515
# Waze Link: https://www.waze.com/en/live-map/directions/subway-avenue-k-lot-uc-8-and-9,-upper-concourse-level,-avenue-k-kuala-lumpur?place=w.66650144.666566972.27413004
#
#
#            Outlet Name                                     Outlet Address  \
# 0  Subway Center Point  Lebuh Bandar Utama, Center Point, Lot G104B Gr...
#
#              Operation Hours  Latitude   Longitude  \
# 0  Monday, 8:00 AM – 10:00PM  3.136096  101.607964
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Center Point
# Outlet Address: Lebuh Bandar Utama, Center Point, Lot G104B Gr Floor, Petaling Jaya, 47800
# Operation Hours: Monday, 8:00 AM – 10:00PM
# Latitude: 3.136096
# Longitude: 101.607964
# Waze Link: https://www.waze.com/en/live-map/directions/subway-lebuh-bandar-utama-lebuh-bandar-utama,-center-point,-lot-g104b-petaling-jaya?place=w.66584607.665911610.27441776
#
#
#                    Outlet Name  \
# 0  Subway Shell Sunway Mentari
#
#                                       Outlet Address  \
# 0  1, Jalan PJS 8/9 (Shell) Bandar Sunway, 46000 ...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday (08:00AM - 10:00PM)  3.079525  101.609623
#
#                                     Waze Link
# 0  https://waze.com/ul?ll=3.079525,101.609623
# Outlet Name: Subway Shell Sunway Mentari
# Outlet Address: 1, Jalan PJS 8/9 (Shell) Bandar Sunway, 46000 Selangor
# Operation Hours: Monday - Sunday (08:00AM - 10:00PM)
# Latitude: 3.079525
# Longitude: 101.609623
# Waze Link: https://waze.com/ul?ll=3.079525,101.609623
#
#
#                    Outlet Name  \
# 0  Subway Berjaya Times Square
#
#                                       Outlet Address  \
# 0  LG-08A, Berjaya Times Square, No. 1, Jalan Imb...
#
#                         Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 10:00 AM - 10:00 PM  3.142198  101.710551
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Berjaya Times Square
# Outlet Address: LG-08A, Berjaya Times Square, No. 1, Jalan Imbi, Kuala Lumpur, 55100
# Operation Hours: Monday - Sunday, 10:00 AM - 10:00 PM
# Latitude: 3.142198
# Longitude: 101.710551
# Waze Link: https://www.waze.com/en/live-map/directions/subway-berjaya-times-square-lot-03-103,-3rd-floor,-berjaya-times-square-kuala-lumpur?place=w.66650143.666566970.27413449
#
#
#         Outlet Name                                     Outlet Address  \
# 0  Subway Capsquare  Ground Floor, Unit 01-02, Cap Square Tower, 10...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Saturday, 8:00 AM – 9:00PM  3.154416  101.698823
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/my...
# Outlet Name: Subway Capsquare
# Outlet Address: Ground Floor, Unit 01-02, Cap Square Tower, 10 Jalan Munshi Abdullah, Kuala Lumpur, 50100
# Operation Hours: Monday - Saturday, 8:00 AM – 9:00PM
# Latitude: 3.154416
# Longitude: 101.698823
# Waze Link: https://www.waze.com/en/live-map/directions/my/wilayah-persekutuan-kuala-lumpur/kuala-lumpur/subway-@-capsquare?place=ChIJy-MVCLdJzDER31pWsrn_WZE
#
#
#        Outlet Name                                     Outlet Address  \
# 0  Subway Aeon AU2  Aeon AU2 Shopping Center, 6, Jln 37/36 Taman S...
#
#                         Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 10:00 AM - 10:00 PM  3.177185  101.750558
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Aeon AU2
# Outlet Address: Aeon AU2 Shopping Center, 6, Jln 37/36 Taman Setiawangsa, Lot G49, Taman Keramat, Kuala Lumpur, 54200
# Operation Hours: Monday - Sunday, 10:00 AM - 10:00 PM
# Latitude: 3.177185
# Longitude: 101.750558
# Waze Link: https://www.waze.com/en/live-map/directions/subway-aeon-au2-aeon-au2-shopping-center-kuala-lumpur?place=w.66715680.666829118.27413005
#
#
#               Outlet Name                                     Outlet Address  \
# 0  Subway Aeon Big Subang  F1-23 AEON BIG, Level 1 No.3 Jalan SS 16/1,Sub...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 9:00 AM - 10:00 PM  3.082580  101.588016
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Aeon Big Subang
# Outlet Address: F1-23 AEON BIG, Level 1 No.3 Jalan SS 16/1,Subang Jaya, Selangor 47500
# Operation Hours: Monday - Sunday, 9:00 AM - 10:00 PM
# Latitude: 3.082580
# Longitude: 101.588016
# Waze Link: https://www.waze.com/en/live-map/directions/subway-aeon-big-f1-23-aeon-big,-level-1-no.3-subang-jaya?place=w.66584607.665780532.27413993
#
#
#                 Outlet Name  \
# 0  Subway University Malaya
#
#                                       Outlet Address  \
# 0  Faculty of Dentistry, Level 1, Block B, Univer...
#
#                       Operation Hours  Latitude   Longitude  \
# 0  Monday - Friday, 6:30 AM – 10:00PM  3.121723  101.653684
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway University Malaya
# Outlet Address: Faculty of Dentistry, Level 1, Block B, University of Malaya, Kuala Lumpur, 50603
# Operation Hours: Monday - Friday, 6:30 AM – 10:00PM
# Latitude: 3.121723
# Longitude: 101.653684
# Waze Link: https://www.waze.com/en/live-map/directions/subway-university-of-malaya-university-of-malaya-faculty-of-dentistry-petaling-jaya?place=w.66650143.666173751.27402188
#
#
# <div class="fp_listitem fp_list_marker19" data-latitude="2.994114" data-longitude="101.758669" style="order: 127;"><div class="location_left"> <h4>Subway Jade Hills</h4> <div class="infoboxcontent"> <p>No 40-G, Jalan Jade Hills Utama 1/2, Commerce Village, Jade Hills, 43000 Kajang, Selangor. </p><p class="infoboxlink"> <a href="/find-a-subway?id=19&amp;view=location" title="Subway Jade Hills">Find out more...</a></p> </div> <div class="infopointer"></div></div><div class="location_right"> <div class="directionButton"><a href="https://goo.gl/maps/Y65Ti6Dk5sEbKCeQ9" target="_blank"><i class="fa-solid fa-location-dot"></i></a><a href="https://www.waze.com/en/live-map/directions/my/selangor/kajang/subway-jade-hill?place=ChIJuRzJknvLzTERiX5pZXHT0gw" target="_blank"><i class="fa-brands fa-waze"></i></a></div></div></div>
#
#
#           Outlet Name                                     Outlet Address  \
# 0  Subway Wangsa Walk  Wangsa Ave, Bandar Wangsa Maju, #9 Jalan Perda...
#
#                       Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 9:30 AM - 9:30 PM  3.198582  101.742206
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Wangsa Walk
# Outlet Address: Wangsa Ave, Bandar Wangsa Maju, #9 Jalan Perdana 1, G-52, Wangsa Walk Mall, Kuala Lumpur, 53300
# Operation Hours: Monday - Sunday, 9:30 AM - 9:30 PM
# Latitude: 3.198582
# Longitude: 101.742206
# Waze Link: https://www.waze.com/en/live-map/directions/subway-wangsa-walk-mall-g-52,-wangsa-walk-mall-kuala-lumpur?place=w.66650144.666763584.27401138
#
#
#    Outlet Name                                     Outlet Address  \
# 0  Subway TTDI  Lvl1, Petronas Svs Station TTDI,Lot29395 & 293...
#
#                       Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 8:30 AM - 9:00 PM  3.141958  101.625217
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/my...
# Outlet Name: Subway TTDI
# Outlet Address: Lvl1, Petronas Svs Station TTDI,Lot29395 & 29396, Pinggir Zaaba, Taman Tun Dr Ismail, Kuala Lumpur, 60000
# Operation Hours: Monday - Sunday, 8:30 AM - 9:00 PM
# Latitude: 3.141958
# Longitude: 101.625217
# Waze Link: https://www.waze.com/en/live-map/directions/my/wilayah-persekutuan-kuala-lumpur/kuala-lumpur/subway-@-pinggir-zaaba-taman-tun?place=ChIJuRYqITBJzDER76oB2espXlU
#
#
#               Outlet Name                                     Outlet Address  \
# 0  Subway Plaza Shah Alam  Lot No. G 17, Ground Floor, Plaza Shah Alam, S...
#
#                       Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 9:30 AM – 09:30PM  3.084338  101.523317
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Plaza Shah Alam
# Outlet Address: Lot No. G 17, Ground Floor, Plaza Shah Alam, Sekysen 9, Shah Alam, 40100
# Operation Hours: Monday - Sunday, 9:30 AM – 09:30PM
# Latitude: 3.084338
# Longitude: 101.523317
# Waze Link: https://www.waze.com/en/live-map/directions/subway-@plaza-shah-alam-lot-g17,-plaza-shah-alam?place=w.66519071.665321780.27398400
#
#
#      Outlet Name                                     Outlet Address  \
# 0  Subway Taipan  7A, Jalan USJ 10/1j, Taipan Business Centre, 4...
#
#                       Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 8:00 AM - 8:00 PM  3.047932  101.586015
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Taipan
# Outlet Address: 7A, Jalan USJ 10/1j, Taipan Business Centre, 47620 Subang Jaya, Selangor
# Operation Hours: Monday - Sunday, 8:00 AM - 8:00 PM
# Latitude: 3.047932
# Longitude: 101.586015
# Waze Link: https://www.waze.com/en/live-map/directions/subway-taipan-jalan-usj-101j-7-subang-jaya?place=w.66584606.665780529.2845552
#
#
#                Outlet Name                                     Outlet Address  \
# 0  Subway Menara Aras Jaya  LG Floor, Menara Bumiputra Commerce, No 11, Ja...
#
#                      Operation Hours  Latitude   Longitude  \
# 0  Monday - Friday, 8:00 AM – 9:00PM  3.155606  101.695688
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Menara Aras Jaya
# Outlet Address: LG Floor, Menara Bumiputra Commerce, No 11, Jalan Raja Laut, 50350 Kuala Lumpur
# Operation Hours: Monday - Friday, 8:00 AM – 9:00PM
# Latitude: 3.155606
# Longitude: 101.695688
# Waze Link: https://www.waze.com/en/live-map/directions/subway-cimb-cimb-11-jalan-raja-laut,-lower-ground-floor-kuala-lumpur?place=w.66650144.666501436.27395039
#
#
#                     Outlet Name  \
# 0  Subway Petronas Ampang Point
#
#                                       Outlet Address  \
# 0  Petronas Gas Station/C-Store, Lot 36904 TT2742...
#
#                       Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 8:30 AM - 9:00 PM  3.160388  101.756010
#
#                                     Waze Link
# 0  https://waze.com/ul?ll=3.160388,101.756010
# Outlet Name: Subway Petronas Ampang Point
# Outlet Address: Petronas Gas Station/C-Store, Lot 36904 TT27423, Jalan Air Kolam Lama, Ampang, 68000
# Operation Hours: Monday - Sunday, 8:30 AM - 9:00 PM
# Latitude: 3.160388
# Longitude: 101.756010
# Waze Link: https://waze.com/ul?ll=3.160388,101.756010
#
#
#            Outlet Name                                     Outlet Address  \
# 0  Subway Tesco Kepong  Tesco Kepong Village Mall, Lot No. 14, 1st Flo...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 10:15 AM - 9:30 PM  3.194423  101.633699
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Tesco Kepong
# Outlet Address: Tesco Kepong Village Mall, Lot No. 14, 1st Floor, No. 3 Jalan 7A/62A Bandar Manjalara, Kuala Lumpur, 52200
# Operation Hours: Monday - Sunday, 10:15 AM - 9:30 PM
# Latitude: 3.194423
# Longitude: 101.633699
# Waze Link: https://www.waze.com/en/live-map/directions/subway-lotuss-kepong-village-lot-no.-14,-1st-floor,-lotuss-kepong-village-mall-kuala-lumpur?place=w.66584608.666042687.27399057
#
#
#          Outlet Name                                     Outlet Address  \
# 0  Subway Jalan Ipoh  No. 447, Jalan Ipoh, Batu 3, Taman Million, 51...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 8:00 AM - 10:00 PM  3.178158  101.685121
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Jalan Ipoh
# Outlet Address: No. 447, Jalan Ipoh, Batu 3, Taman Million, 51200 Kuala Lumpur
# Operation Hours: Monday - Sunday, 8:00 AM - 10:00 PM
# Latitude: 3.178158
# Longitude: 101.685121
# Waze Link: https://www.waze.com/en/live-map/directions/subway-rivercity-village-468-1(1),-ground-floor,-block-f-rivercity-village-kuala-lumpur?place=w.66650144.666370366.16193787
#
#
#             Outlet Name                                     Outlet Address  \
# 0  Subway Selayang Mall  Selayang Mall, GSW .5A, Ground Floor, Batu Cav...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 9:00 AM - 10:00 PM  3.237131  101.643784
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Selayang Mall
# Outlet Address: Selayang Mall, GSW .5A, Ground Floor, Batu Caves, 68100
# Operation Hours: Monday - Sunday, 9:00 AM - 10:00 PM
# Latitude: 3.237131
# Longitude: 101.643784
# Waze Link: https://www.waze.com/en/live-map/directions/subway-selayang-mall-5a,-ground-floor,-selayang-mall-batu-caves?place=w.66584608.666108228.27398140
#
#
#                Outlet Name                                     Outlet Address  \
# 0  Subway AEON BIG Puchong  AEON BIG Shopping Center, Lot No G04 Ground Fl...
#
#                         Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 10:00 AM - 10:00 PM  2.991741  101.615601
#
#                                            Waze Link
# 0  https://ul.waze.com/ul?preview_venue_id=665846...
# Outlet Name: Subway AEON BIG Puchong
# Outlet Address: AEON BIG Shopping Center, Lot No G04 Ground Floor, Lot 4029 Persiaran Selangor, Puchong Utama, 47100
# Operation Hours: Monday - Sunday, 10:00 AM - 10:00 PM
# Latitude: 2.991741
# Longitude: 101.615601
# Waze Link: https://ul.waze.com/ul?preview_venue_id=66584606.665911595.26934483&navigate=yes&utm_campaign=default&utm_source=waze_website&utm_medium=lm_share_location
#
#
#          Outlet Name                                     Outlet Address  \
# 0  Subway Seksyen 13  Tadisma Business Park, Seksyen 13, 40100 Shah ...
#
#                       Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday (9:30AM - 10:30PM)  3.089032  101.546357
#
#                                     Waze Link
# 0  https://waze.com/ul?ll=3.089032,101.546357
# Outlet Name: Subway Seksyen 13
# Outlet Address: Tadisma Business Park, Seksyen 13, 40100 Shah Alam, Selangor
# Operation Hours: Monday - Sunday (9:30AM - 10:30PM)
# Latitude: 3.089032
# Longitude: 101.546357
# Waze Link: https://waze.com/ul?ll=3.089032,101.546357
#
#
#           Outlet Name                                     Outlet Address  \
# 0  Subway Axis Atrium  Axis Atrium, Lot No. G-3 Ground Floor, Jalan C...
#
#                       Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 8:00 AM - 9:00 PM  3.136505  101.747491
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Axis Atrium
# Outlet Address: Axis Atrium, Lot No. G-3 Ground Floor, Jalan Cempaka, Taman Cempaka Ampang, 68000
# Operation Hours: Monday - Sunday, 8:00 AM - 9:00 PM
# Latitude: 3.136505
# Longitude: 101.747491
# Waze Link: https://www.waze.com/en/live-map/directions/subway-axis-atrium-axis-atrium,-lot-no.-g-3-ground-floor-kuala-lumpur?place=w.66650143.666829114.27401140
#
#
#                   Outlet Name  \
# 0  Subway Taman Prima Saujana
#
#                                       Outlet Address  \
# 0  G-2A-GB, Jalan Prima Saujana 2/D, Taman Prima ...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 8:00 AM - 10:00 PM  3.008788  101.804503
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/my...
# Outlet Name: Subway Taman Prima Saujana
# Outlet Address: G-2A-GB, Jalan Prima Saujana 2/D, Taman Prima Saujana, 43000 Kajang, Selangor
# Operation Hours: Monday - Sunday, 8:00 AM - 10:00 PM
# Latitude: 3.008788
# Longitude: 101.804503
# Waze Link: https://www.waze.com/en/live-map/directions/my/selangor/kajang/subway-prima-saujana?place=ChIJ5T1_lhrNzTERznG7echZSEc
#
#
#           Outlet Name                                     Outlet Address  \
# 0  Subway Cova Square  G16, Cova Square Jalan Teknologi Pju5 Kota Dam...
#
#                       Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 8:00 AM - 9:00 PM  3.147444  101.575434
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Cova Square
# Outlet Address: G16, Cova Square Jalan Teknologi Pju5 Kota Damansara 47810 Petaling Jaya Selangor
# Operation Hours: Monday - Sunday, 8:00 AM - 9:00 PM
# Latitude: 3.147444
# Longitude: 101.575434
# Waze Link: https://www.waze.com/en/live-map/directions/subway-cova-square-jalan-teknologi-16-petaling-jaya?place=w.66584607.665649467.17215766
#
#
#                               Outlet Name  \
# 0  Subway Giant Bandar Kinrara  - Puchong
#
#                                       Outlet Address  \
# 0  Giant Hypermkt Bandar Kinrara, Lot No:G8, Lot ...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 9
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway KWC (Kenanga)
# Outlet Address: KWC Fashion Mall, No.2, Jalan Gelugor, Lot G-08, Kuala Lumpur, 55200
# Operation Hours: Monday - Sunday, 10:00 AM - 8:00 PM
# Latitude: 3.136102
# Longitude: 101.708431
# Waze Link: https://www.waze.com/en/live-map/directions/subway-kwc-fashion-mall-lot-g-08-kwc-fashion-mall-kuala-lumpur?place=w.66650143.666566970.27400904
#
#
#           Outlet Name                                     Outlet Address  \
# 0  Subway Selayang 18  Lot 3.06, 3rd Floor vendor letter SH-15-G,Grd ...
#
#                       Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 8:00 AM - 9:00 PM  3.255174  101.654411
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Selayang 18
# Outlet Address: Lot 3.06, 3rd Floor vendor letter SH-15-G,Grd Floor,Selayang, Kuala Lumpur, 68000 , Batu Caves, 68100
# Operation Hours: Monday - Sunday, 8:00 AM - 9:00 PM
# Latitude: 3.255174
# Longitude: 101.654411
# Waze Link: https://www.waze.com/en/live-map/directions/subway-selayang-18-persiaran-3-batu-caves?place=w.66650145.666173766.21949236
#
#
#                   Outlet Name  \
# 0  Subway Sime Darby Parkcity
#
#                                       Outlet Address  \
# 0  Sime Darby Parkcity, CP Retail 2, No. 2 Jalan ...
#
#                       Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 8:00 AM - 9:30 PM  3.189334  101.638541
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Sime Darby Parkcity
# Outlet Address: Sime Darby Parkcity, CP Retail 2, No. 2 Jalan Intisari, Perdana Desa Parkcity, Kuala Lumpur, 52200
# Operation Hours: Monday - Sunday, 8:00 AM - 9:30 PM
# Latitude: 3.189334
# Longitude: 101.638541
# Waze Link: https://www.waze.com/en/live-map/directions/subway-desa-park-city-sime-darby-parkcity,-cp-retail-2-kuala-lumpur?place=w.66584608.666108223.14350474
#
#
#   Outlet Name                                     Outlet Address  \
# 0   Subway TM  Lower Ground 1 (LG1), Menara TM, Jalan Pantai ...
#
#              Operation Hours  Latitude   Longitude  \
# 0  Monday, 10:00 AM – 8:00PM  3.116129  101.665866
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/my...
# Outlet Name: Subway TM
# Outlet Address: Lower Ground 1 (LG1), Menara TM, Jalan Pantai Baharu, 50672 Kuala Lumpur
# Operation Hours: Monday, 10:00 AM – 8:00PM
# Latitude: 3.116129
# Longitude: 101.665866
# Waze Link: https://www.waze.com/en/live-map/directions/my/federal-territory-of-kuala-lumpur/kuala-lumpur/subway-@-menara-tm?place=ChIJ97qHTY1JzDEREeRr6wtfSts
#
#
#   Outlet Name                                     Outlet Address  \
# 0  Subway GPS  Petronas Green Plus Station, Plus Hwy & Sungai...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 8:00 AM - 11:00 PM  3.005880  101.725544
#
#                                     Waze Link
# 0  https://waze.com/ul?ll=3.005880,101.725544
# Outlet Name: Subway GPS
# Outlet Address: Petronas Green Plus Station, Plus Hwy & Sungai Besi Hwy, Lot 896, Ground Floor, QSR 3, Mukim Kajang, Hulu Langat, 43300
# Operation Hours: Monday - Sunday, 8:00 AM - 11:00 PM
# Latitude: 3.005880
# Longitude: 101.725544
# Waze Link: https://waze.com/ul?ll=3.005880,101.725544
#
#
#             Outlet Name                                     Outlet Address  \
# 0  Subway Sunway Lagoon  Sunway Lagoon Theme Park, FB-Z-001, 3, Jalan P...
#
#                                      Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday (10:00AM - 6:00PM)Tuesday : Close  3.071533  101.605323
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Sunway Lagoon
# Outlet Address: Sunway Lagoon Theme Park, FB-Z-001, 3, Jalan PJS 11/11, Bandar Sunway, Petaling Jaya, 46150
# Operation Hours: Monday - Sunday (10:00AM - 6:00PM)Tuesday : Close
# Latitude: 3.071533
# Longitude: 101.605323
# Waze Link: https://www.waze.com/en/live-map/directions/subway-sunway-lagoon-sunway-lagoon-theme-park,-fb-z-001,-3-petaling-jaya?place=w.66584607.665911603.27401305
#
#
#          Outlet Name                                     Outlet Address  \
# 0  Subway Sri Gombak  No. G100, Jalan Prima SG3/2, Taman Prima, Sri ...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 8:00 AM - 10:30 PM  3.237666  101.700343
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/my...
# Outlet Name: Subway Sri Gombak
# Outlet Address: No. G100, Jalan Prima SG3/2, Taman Prima, Sri Gombak, Kuala Lumpur, 68100
# Operation Hours: Monday - Sunday, 8:00 AM - 10:30 PM
# Latitude: 3.237666
# Longitude: 101.700343
# Waze Link: https://www.waze.com/en/live-map/directions/my/selangor/batu-caves/subway?place=ChIJi5BmZXtHzDER519jKGFtoFk
#
#
#                     Outlet Name  \
# 0  Subway Trillium, Lake Fields
#
#                                       Outlet Address  \
# 0  No.66, Jalan Tasik Utama 7, Medan Niaga Tasik ...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 8:30 AM - 10:00 PM  3.059890  101.710432
#
#                                     Waze Link
# 0  https://waze.com/ul?ll=3.059890,101.710432
# Outlet Name: Subway Trillium, Lake Fields
# Outlet Address: No.66, Jalan Tasik Utama 7, Medan Niaga Tasik Damai, (Trillium) Lake Field, Sg Besi, Kuala Lumpur, 57000
# Operation Hours: Monday - Sunday, 8:30 AM - 10:00 PM
# Latitude: 3.059890
# Longitude: 101.710432
# Waze Link: https://waze.com/ul?ll=3.059890,101.710432
#
#
#              Outlet Name                                     Outlet Address  \
# 0  Subway Ikon Connaught  Ikon Connaught, G-02A & Alfresco GA-02A, Groun...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 10:00 AM - 8:00 PM  3.081465  101.731419
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Ikon Connaught
# Outlet Address: Ikon Connaught, G-02A & Alfresco GA-02A, Ground Floor, Jalan Cerdas, Taman Connaught, Kuala Lumpur, 56100
# Operation Hours: Monday - Sunday, 10:00 AM - 8:00 PM
# Latitude: 3.081465
# Longitude: 101.731419
# Waze Link: https://www.waze.com/en/live-map/directions/subway-ikon-connaught-lot-g-02a-ikon-connaught-kuala-lumpur?place=w.66650143.666698036.27398136
#
#
#     Outlet Name                                     Outlet Address  \
# 0  Subway Atria  Atria Shopping Gallery, Lot C11, Jalan SS 22/2...
#
#                         Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 10:00 AM - 10:00 PM  3.127096  101.616518
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Atria
# Outlet Address: Atria Shopping Gallery, Lot C11, Jalan SS 22/23, Damansara Jaya, Petaling Jaya, 47400
# Operation Hours: Monday - Sunday, 10:00 AM - 10:00 PM
# Latitude: 3.127096
# Longitude: 101.616518
# Waze Link: https://www.waze.com/en/live-map/directions/subway-atria-shoppinggallery-lot-c11-atria-shopping-gallery-petaling-jaya?place=w.66584607.665977145.27398112
#
#
#   Outlet Name                                     Outlet Address  \
# 0  Subway SS3  Jalan SS3/39, Ground Floor, Unit 16, Bangunan ...
#
#                         Operation Hours  Latitude   Longitude  \
# 0  Monday - Saturday, 8:00 AM – 10:00PM  3.090677  101.614668
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/my...
# Outlet Name: Subway SS3
# Outlet Address: Jalan SS3/39, Ground Floor, Unit 16, Bangunan PJ21, Petaling Jaya, 47300
# Operation Hours: Monday - Saturday, 8:00 AM – 10:00PM
# Latitude: 3.090677
# Longitude: 101.614668
# Waze Link: https://www.waze.com/en/live-map/directions/my/selangor/pj/subway-ss3?place=ChIJuTzSm3VMzDERLk_bVVw9iTg
#
#
#           Outlet Name                                     Outlet Address  \
# 0  Subway Ativo Plaza  Ativo Plaza, #1 Jalan PJU 9/1, Damansara Ave, ...
#
#                         Operation Hours  Latitude   Longitude  \
# 0  Monday - Saturday, 8:30 AM – 10:00PM  3.196263  101.616271
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Ativo Plaza
# Outlet Address: Ativo Plaza, #1 Jalan PJU 9/1, Damansara Ave, B-G-2, Block B, Bandar Sri Damansara, Kuala Lumpur, 52200
# Operation Hours: Monday - Saturday, 8:30 AM – 10:00PM
# Latitude: 3.196263
# Longitude: 101.616271
# Waze Link: https://www.waze.com/en/live-map/directions/subway-ativo-plaza-jalan-pju-91-kuala-lumpur?place=w.66584608.665977152.5632979
#
#
#               Outlet Name                                     Outlet Address  \
# 0  Subway Quill City (LG)  Quill City Mall, LG-02, No. 1018, Jalan Sultan...
#
#                         Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 10:00 AM - 10:00 PM  3.159488  101.700170
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/my...
# Outlet Name: Subway Quill City (LG)
# Outlet Address: Quill City Mall, LG-02, No. 1018, Jalan Sultan Ismail, Kuala Lumpur , 50250
# Operation Hours: Monday - Sunday, 10:00 AM - 10:00 PM
# Latitude: 3.159488
# Longitude: 101.700170
# Waze Link: https://www.waze.com/en/live-map/directions/my/federal-territory-of-kuala-lumpur/kuala-lumpur/subway-@-quill-city-mall?place=ChIJl7-7OS9IzDERa282ngJCTKs
#
#
#        Outlet Name                                     Outlet Address  \
# 0  Subway Sunway U  No. 27 Jalan PJS 11/9, Bandar Sunway, Petaling...
#
#                       Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 9:00 AM - 8:00 PM  3.067818  101.603107
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Sunway U
# Outlet Address: No. 27 Jalan PJS 11/9, Bandar Sunway, Petaling Jaya, 46150
# Operation Hours: Monday - Sunday, 9:00 AM - 8:00 PM
# Latitude: 3.067818
# Longitude: 101.603107
# Waze Link: https://www.waze.com/en/live-map/directions/subway-sunway-university-no.-27-jalan-pjs-119,-bandar-sunway,-46150-subang-jaya?place=w.66584607.665846067.26717443
#
#
#              Outlet Name                                     Outlet Address  \
# 0  Subway Kota Damansara  15-1, Jalan PJU 5/6, Dataran Sunway, Kota Dama...
#
#                       Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 8:00 AM - 8:00 PM  3.153206  101.594907
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/my...
# Outlet Name: Subway Kota Damansara
# Outlet Address: 15-1, Jalan PJU 5/6, Dataran Sunway, Kota Damansara, Petaling Jaya, 47810
# Operation Hours: Monday - Sunday, 8:00 AM - 8:00 PM
# Latitude: 3.153206
# Longitude: 101.594907
# Waze Link: https://www.waze.com/en/live-map/directions/my/selangor/pj/subway-@-dataran-sunway?place=ChIJjaT4bSBPzDERdko25w89Fq8
#
#
#   Outlet Name                                     Outlet Address  \
# 0  Subway OUG  A1-07 Jalan 1/52, Taman OUG Parklane Off Jalan...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 9:00 AM - 10:00 PM  3.074779  101.661593
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/my...
# Outlet Name: Subway OUG
# Outlet Address: A1-07 Jalan 1/52, Taman OUG Parklane Off Jalan Klang Lama 58200 Kuala Lumpur
# Operation Hours: Monday - Sunday, 9:00 AM - 10:00 PM
# Latitude: 3.074779
# Longitude: 101.661593
# Waze Link: https://www.waze.com/en/live-map/directions/my/wilayah-persekutuan-kuala-lumpur/kuala-lumpur/subway-oug-parklane?place=ChIJW9BS3nlLzDERdemjQm9QkBE
#
#
#              Outlet Name                                     Outlet Address  \
# 0  Subway Petronas Kesas  Petronas Station, Lebuhraya Kesas Arah Barat K...
#
#                         Operation Hours  Latitude   Longitude  \
# 0  Monday - Saturday, 7:30 AM – 10:00PM  3.050101  101.563370
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/my...
# Outlet Name: Subway Petronas Kesas
# Outlet Address: Petronas Station, Lebuhraya Kesas Arah Barat KM34.5, Lebuhraya Kesas, 40000 Shah Alam, Selangor
# Operation Hours: Monday - Saturday, 7:30 AM – 10:00PM
# Latitude: 3.050101
# Longitude: 101.563370
# Waze Link: https://www.waze.com/en/live-map/directions/my/selangor/subang-jaya/subway-petronas-kesas-highway-arah-barat-km34.-5?place=ChIJ9bLY5B5NzDERCu0iuXkBptY
#
#
#            Outlet Name                                     Outlet Address  \
# 0  Subway Sri Petaling  No. 53, Jalan Radin Bagus, 57000 Sri Petaling,...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 8:00 AM - 10:00 PM  3.070392  101.695026
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Sri Petaling
# Outlet Address: No. 53, Jalan Radin Bagus, 57000 Sri Petaling, Kuala Lumpur
# Operation Hours: Monday - Sunday, 8:00 AM - 10:00 PM
# Latitude: 3.070392
# Longitude: 101.695026
# Waze Link: https://www.waze.com/en/live-map/directions/subway-sri-petaling-jalan-radin-bagus-53-kuala-lumpur?place=w.66650143.666435891.12280737
#
#
#            Outlet Name                                     Outlet Address  \
# 0  Subway Puncak Jalil   116 Jalan PUJ 3/2,Taman Puncak Jalil, Bandar ...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 9:00 AM - 10:00 PM  3.020222  101.675020
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/my...
# Outlet Name: Subway Puncak Jalil
# Outlet Address:  116 Jalan PUJ 3/2,Taman Puncak Jalil, Bandar Putra Permai,Seri Kembangan, 63300
# Operation Hours: Monday - Sunday, 9:00 AM - 10:00 PM
# Latitude: 3.020222
# Longitude: 101.675020
# Waze Link: https://www.waze.com/en/live-map/directions/my/selangor/seri-kembangan/subway?place=ChIJzXasDDu1zTERjmQ2GXJQHxk
#
#
#                Outlet Name                                     Outlet Address  \
# 0  Subway Aeon Alpha Angle  AEON Alpha Angle Shopping Ctr, Lot F37A, Jalan...
#
#                         Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 10:00 AM - 10:00 PM  3.201844  101.731845
#
#                                            Waze Link
# ...
#                                     Waze Link
# 0  https://waze.com/ul?ll=3.222777,101.670945
# Outlet Name: Subway Lotuss Selayang
# Outlet Address: Lot F-18 & 18 (External) No. 1081, Jalan Ipoh Mukim Batu 51200 Kuala Lumpur
# Operation Hours: Monday - Sunday (10:00AM - 10:00PM)
# Latitude: 3.222777
# Longitude: 101.670945
# Waze Link: https://waze.com/ul?ll=3.222777,101.670945
#
#
#           Outlet Name                                     Outlet Address  \
# 0  Subway Hartamas SC  Lot G-22A & G-22B . Hartamas Shopping Center, ...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday (10:00AM - 10:00PM)  3.163504  101.656995
#
#                                     Waze Link
# 0  https://waze.com/ul?ll=3.163504,101.656995
# Outlet Name: Subway Hartamas SC
# Outlet Address: Lot G-22A & G-22B . Hartamas Shopping Center, 60, Jalan Sri Hartamas 1, Taman Sri Hartamas, 50480 Kuala Lumpur, Wilayah Persekutuan Kuala Lumpur
# Operation Hours: Monday - Sunday (10:00AM - 10:00PM)
# Latitude: 3.163504
# Longitude: 101.656995
# Waze Link: https://waze.com/ul?ll=3.163504,101.656995
#
#
#             Outlet Name                                     Outlet Address  \
# 0  Subway Paradigm Mall  LG-33A(P), LG Floor No. 1, Jalan SS7/26A Kelan...
#
#                         Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 10:00 AM - 10:00 PM  3.105084  101.596048
#
#                                     Waze Link
# 0  https://waze.com/ul?ll=3.105084,101.596048
# Outlet Name: Subway Paradigm Mall
# Outlet Address: LG-33A(P), LG Floor No. 1, Jalan SS7/26A Kelana Jaya 47301 Petaling Jaya Selangor
# Operation Hours: Monday - Sunday, 10:00 AM - 10:00 PM
# Latitude: 3.105084
# Longitude: 101.596048
# Waze Link: https://waze.com/ul?ll=3.105084,101.596048
#
#
#     Outlet Name                                     Outlet Address  \
# 0  Subway Damen  LG38, Lower Ground Floor Damen USJ 1 Jalan Per...
#
#                         Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 10:00 AM - 10:00 PM  3.058525  101.592670
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/my...
# Outlet Name: Subway Damen
# Outlet Address: LG38, Lower Ground Floor Damen USJ 1 Jalan Persiaran Kewajipan USJ 1 47600 Subang Jaya
# Operation Hours: Monday - Sunday, 10:00 AM - 10:00 PM
# Latitude: 3.058525
# Longitude: 101.592670
# Waze Link: https://www.waze.com/en/live-map/directions/my/selangor/subang-jaya/subway-da-men?place=ChIJ9-92ti9NzDERgRUlEJ3Y8Wc
#
#
#                Outlet Name                                     Outlet Address  \
# 0  Subway Tropicana Garden  CC-K55A, Concourse Floor, No. 2A, Persiaran Su...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday (10:00AM - 10:00PM)  3.149188  101.593094
#
#                                     Waze Link
# 0  https://waze.com/ul?ll=3.149188,101.593094
# Outlet Name: Subway Tropicana Garden
# Outlet Address: CC-K55A, Concourse Floor, No. 2A, Persiaran Surian Tropicana Indah, 47810 Petaling Jaya, Selangor
# Operation Hours: Monday - Sunday (10:00AM - 10:00PM)
# Latitude: 3.149188
# Longitude: 101.593094
# Waze Link: https://waze.com/ul?ll=3.149188,101.593094
#
#
#          Outlet Name                                     Outlet Address  \
# 0  Subway Main Place  LG33, Main Place Mall USJ, Jalan USJ 21/10, Pe...
#
#                         Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 10:00 AM - 10:00 PM  3.026320  101.581147
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/my...
# Outlet Name: Subway Main Place
# Outlet Address: LG33, Main Place Mall USJ, Jalan USJ 21/10, Persiaran Kewajipan, 47630 Subang Jaya, Selangor.
# Operation Hours: Monday - Sunday, 10:00 AM - 10:00 PM
# Latitude: 3.026320
# Longitude: 101.581147
# Waze Link: https://www.waze.com/en/live-map/directions/my/selangor/subang-jaya/subway?place=ChIJjb3QkzGzzTERYh-RwcOFeEY
#
#
#              Outlet Name                                     Outlet Address  \
# 0  Subway Intermark Mall  The Intermark, Intermark Mall, 348, Jalan Tun ...
#
#                         Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 10:00 AM - 10:00 PM  3.161545  101.719918
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/my...
# Outlet Name: Subway Intermark Mall
# Outlet Address: The Intermark, Intermark Mall, 348, Jalan Tun Razak, 50400 Kuala Lumpur
# Operation Hours: Monday - Sunday, 10:00 AM - 10:00 PM
# Latitude: 3.161545
# Longitude: 101.719918
# Waze Link: https://www.waze.com/en/live-map/directions/my/wilayah-persekutuan-kuala-lumpur/kuala-lumpur/subway-the-intermark?place=ChIJ48goZMU3zDERrTBFRU1gP-Mhttps://www.waze.com/en/live-map/directions/my/wilayah-persekutuan-kuala-lumpur/kuala-lumpur/subway-the-intermark?place=ChIJ48goZMU3zDERrTBFRU1gP-M
#
#
#              Outlet Name                                     Outlet Address  \
# 0  Subway Central Square  23 Jalan Kampung Baru Lot GK-02 Central Square...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 9:00 AM - 10:00 PM  3.163051  101.706183
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/su...
# Outlet Name: Subway Central Square
# Outlet Address: 23 Jalan Kampung Baru Lot GK-02 Central Square Shopping Center, 08000 Sungai Petani, Kedah
# Operation Hours: Monday - Sunday, 9:00 AM - 10:00 PM
# Latitude: 3.163051
# Longitude: 101.706183
# Waze Link: https://www.waze.com/en/live-map/directions/subway-central-square-lot-gk-02,-central-square-shopping-center-sungai-petani?place=w.65863736.658571828.27396324
#
#
#              Outlet Name                                     Outlet Address  \
# 0  Subway The Grand SS15  G7, The Grand Subang Jaya, Jalan SS 15/8a, Ss ...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 8:00 AM - 10:00 PM  3.074415  101.590297
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/my...
# Outlet Name: Subway The Grand SS15
# Outlet Address: G7, The Grand Subang Jaya, Jalan SS 15/8a, Ss 15, 47500 Subang Jaya, Selangor
# Operation Hours: Monday - Sunday, 8:00 AM - 10:00 PM
# Latitude: 3.074415
# Longitude: 101.590297
# Waze Link: https://www.waze.com/en/live-map/directions/my/selangor/subang-jaya/subway-the-grand-subang-jaya?place=ChIJJxTAK6JNzDER4MbW2WX_jG0
#
#
#                    Outlet Name  \
# 0  Subway Radia Bukit Jelutong
#
#                                       Outlet Address  \
# 0  G0-23, Radia Sales Gallery, Persiaran Arked, B...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 7:30 AM - 10:00 PM  3.101122  101.535394
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/my...
# Outlet Name: Subway Radia Bukit Jelutong
# Outlet Address: G0-23, Radia Sales Gallery, Persiaran Arked, Bukit Jelutong, 40150 Shah Alam, Selangor
# Operation Hours: Monday - Sunday, 7:30 AM - 10:00 PM
# Latitude: 3.101122
# Longitude: 101.535394
# Waze Link: https://www.waze.com/en/live-map/directions/my/selangor/shah-alam/subway-radia-bukit-jelutong?place=ChIJ98G9H_JNzDERRS_vEqme9_s
#
#
#                Outlet Name                                     Outlet Address  \
# 0  Subway Kelana Jaya (KJ)  Suite 109b, Ground Floor, Office Tower, Kelana...
#
#                       Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 8:30 AM - 8:30 PM  3.100862  101.599716
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/my...
# Outlet Name: Subway Kelana Jaya (KJ)
# Outlet Address: Suite 109b, Ground Floor, Office Tower, Kelana Park View, No.1, Jalan SS6/2, 47301 Petaling Jaya, Selangor
# Operation Hours: Monday - Sunday, 8:30 AM - 8:30 PM
# Latitude: 3.100862
# Longitude: 101.599716
# Waze Link: https://www.waze.com/en/live-map/directions/my/selangor/pj/subway-kelana-jaya-or-kelana-parkview?place=ChIJRU4RwhBMzDERZ_FO9UjGJ7g
#
#
#                 Outlet Name  \
# 0  Subway Sierra 16 Puchong
#
#                                       Outlet Address  \
# 0  Lot 3A-1, Sierra Fresco, Jln Sierra 10/1, Band...
#
#                       Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday (8:00AM - 10:00PM)  2.974426  101.655052
#
#                                            Waze Link
# 0  https://www.waze.com/en/live-map/directions/my...
# Outlet Name: Subway Sierra 16 Puchong
# Outlet Address: Lot 3A-1, Sierra Fresco, Jln Sierra 10/1, Bandar 16 Sierra, 47110 Puchong, Selangor.
# Operation Hours: Monday - Sunday (8:00AM - 10:00PM)
# Latitude: 2.974426
# Longitude: 101.655052
# Waze Link: https://www.waze.com/en/live-map/directions/my/selangor/puchong/subway16sierra?place=ChIJ4cJ0tYW1zTERx74e0tVmW9g
#
#
#                         Outlet Name  \
# 0  Subway Caltex Bukit Indah Ampang
#
#                                       Outlet Address  \
# 0  Caltex Bukit Indah, PT13887, Medan Bukit Indah...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday, 8:00 AM - 10:00 PM  3.152855  101.774414
#
#                                     Waze Link
# 0  https://waze.com/ul?ll=3.152855,101.774414
# Outlet Name: Subway Caltex Bukit Indah Ampang
# Outlet Address: Caltex Bukit Indah, PT13887, Medan Bukit Indah, Taman Bukit Indah, 69000 Ampang, Selangor
# Operation Hours: Monday - Sunday, 8:00 AM - 10:00 PM
# Latitude: 3.152855
# Longitude: 101.774414
# Waze Link: https://waze.com/ul?ll=3.152855,101.774414
#
#
#                Outlet Name Outlet Address Operation Hours  Latitude  \
# 0  Subway Taman Danau Desa                                 3.100857
#
#     Longitude                                   Waze Link
# 0  101.687222  https://waze.com/ul?ll=3.100857,101.687222
# Outlet Name: Subway Taman Danau Desa
# Outlet Address:
# Operation Hours:
# Latitude: 3.100857
# Longitude: 101.687222
# Waze Link: https://waze.com/ul?ll=3.100857,101.687222
#
#
#                    Outlet Name  \
# 0  Subway Setapak Central Mall
#
#                                       Outlet Address  \
# 0  Kl Festival City, Lot S-23, No 67 Jalan Taman ...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday (10:00AM - 10:00PM)  3.205267  101.720020
#
#                                     Waze Link
# 0  https://waze.com/ul?ll=3.205267,101.720020
# Outlet Name: Subway Setapak Central Mall
# Outlet Address: Kl Festival City, Lot S-23, No 67 Jalan Taman Ibu Kota, Taman Danau Kota, Setapak, Kuala Lumpur, 53200
# Operation Hours: Monday - Sunday (10:00AM - 10:00PM)
# Latitude: 3.205267
# Longitude: 101.720020
# Waze Link: https://waze.com/ul?ll=3.205267,101.720020
#
#
#           Outlet Name                                     Outlet Address  \
# 0  Subway Taman Ehsan  No 520(GF) Jalan E3/8, Tmn Ehsan, 52100 Kepong...
#
#                       Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday (8:00AM - 10:00PM)  3.220409  101.622847
#
#                                     Waze Link
# 0  https://waze.com/ul?ll=3.220409,101.622847
# Outlet Name: Subway Taman Ehsan
# Outlet Address: No 520(GF) Jalan E3/8, Tmn Ehsan, 52100 Kepong, Selangor
# Operation Hours: Monday - Sunday (8:00AM - 10:00PM)
# Latitude: 3.220409
# Longitude: 101.622847
# Waze Link: https://waze.com/ul?ll=3.220409,101.622847
#
#
#              Outlet Name                                     Outlet Address  \
# 0  Subway Taman Sri Muda  No 40 (GF), Jalan Murni 25/61, Taman Sri Muda,...
#
#                       Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday (8:00AM - 10:00PM)  3.032726  101.536497
#
#                                     Waze Link
# 0  https://waze.com/ul?ll=3.032726,101.536497
# Outlet Name: Subway Taman Sri Muda
# Outlet Address: No 40 (GF), Jalan Murni 25/61, Taman Sri Muda, 40400 Shah Alam, Selangor
# Operation Hours: Monday - Sunday (8:00AM - 10:00PM)
# Latitude: 3.032726
# Longitude: 101.536497
# Waze Link: https://waze.com/ul?ll=3.032726,101.536497
#
#
#             Outlet Name                                     Outlet Address  \
# 0  Subway Mid Valley KL  1st Floor, Zone 3, Kiosk FK-05, Mid Valley Meg...
#
#                       Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday (8:00AM - 10:00PM)  3.118753  101.677459
#
#                                     Waze Link
# 0  https://waze.com/ul?ll=3.118753,101.677459
# Outlet Name: Subway Mid Valley KL
# Outlet Address: 1st Floor, Zone 3, Kiosk FK-05, Mid Valley Megamall,  Lingkaran Syed Putra, Mid Valley City, 59200 Kuala Lumpur
# Operation Hours: Monday - Sunday (8:00AM - 10:00PM)
# Latitude: 3.118753
# Longitude: 101.677459
# Waze Link: https://waze.com/ul?ll=3.118753,101.677459
#
#
#            Outlet Name                                     Outlet Address  \
# 0  Subway Lotus Ampang  LOTUS’S AMPANG - OL1, Jalan Pandan Prima Datar...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday (10:00AM - 10:00PM)  3.143814  101.741630
#
#                                     Waze Link
# 0  https://waze.com/ul?ll=3.143814,101.741630
# Outlet Name: Subway Lotus Ampang
# Outlet Address: LOTUS’S AMPANG - OL1, Jalan Pandan Prima Dataran, Pandan Indah, 55100 Kuala Lumpur
# Operation Hours: Monday - Sunday (10:00AM - 10:00PM)
# Latitude: 3.143814
# Longitude: 101.741630
# Waze Link: https://waze.com/ul?ll=3.143814,101.741630
#
#
#          Outlet Name                                     Outlet Address  \
# 0  Subway Razak City  Block B-G-19 Residensi Bandar Razak, No 01 Jln...
#
#                         Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday (08:00AM to 10:00PM)  3.108465  101.706308
#
#                                     Waze Link
# 0  https://waze.com/ul?ll=3.108465,101.706308
# Outlet Name: Subway Razak City
# Outlet Address: Block B-G-19 Residensi Bandar Razak, No 01 Jln Razak Mansion, 57100 Sungai Besi, K.L
# Operation Hours: Monday - Sunday (08:00AM to 10:00PM)
# Latitude: 3.108465
# Longitude: 101.706308
# Waze Link: https://waze.com/ul?ll=3.108465,101.706308
#
#
#                   Outlet Name  \
# 0  Subway Aeon Cheras Selatan
#
#                                       Outlet Address  \
# 0  F60, First Floor, ÆON Cheras Selatan, Lebuh Ut...
#
#                         Operation Hours  Latitude   Longitude  \
# 0  Monday to Sunday (10:00AM - 10:00PM)  3.033015  101.765206
#
#                                     Waze Link
# 0  https://waze.com/ul?ll=3.033015,101.765206
# Outlet Name: Subway Aeon Cheras Selatan
# Outlet Address: F60, First Floor, ÆON Cheras Selatan, Lebuh Utama Tun Hussein Onn, Tun Hussein Onn, Cheras, Selangor
# Operation Hours: Monday to Sunday (10:00AM - 10:00PM)
# Latitude: 3.033015
# Longitude: 101.765206
# Waze Link: https://waze.com/ul?ll=3.033015,101.765206
#
#
#         Outlet Name                                     Outlet Address  \
# 0  Subway Kiara Bay  "Lot G-22, The Beat Kiara Bay Kepong Metropoli...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday (10:00AM - 10:00PM)  3.226999  101.650259
#
#                                     Waze Link
# 0  https://waze.com/ul?ll=3.226999,101.650259
# Outlet Name: Subway Kiara Bay
# Outlet Address: "Lot G-22, The Beat Kiara Bay Kepong Metropolitan Park,Jalan Lingkaran Tengah 52100 Kuala Lumpur."
# Operation Hours: Monday - Sunday (10:00AM - 10:00PM)
# Latitude: 3.226999
# Longitude: 101.650259
# Waze Link: https://waze.com/ul?ll=3.226999,101.650259
#
#
#            Outlet Name                                     Outlet Address  \
# 0  Subway Putra Ampang  No 46-G, Jalan Bunga Tanjung 9B, Taman Putra, ...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday (08:00AM - 10:00PM)  3.120457  101.762861
#
#                                     Waze Link
# 0  https://waze.com/ul?ll=3.120457,101.762861
# Outlet Name: Subway Putra Ampang
# Outlet Address: No 46-G, Jalan Bunga Tanjung 9B, Taman Putra, Ampang 68000, Selangor
# Operation Hours: Monday - Sunday (08:00AM - 10:00PM)
# Latitude: 3.120457
# Longitude: 101.762861
# Waze Link: https://waze.com/ul?ll=3.120457,101.762861

# %%
df.head()
# Out:
#            Outlet Name                                     Outlet Address  \
# 0  Subway Putra Ampang  No 46-G, Jalan Bunga Tanjung 9B, Taman Putra, ...
#
#                        Operation Hours  Latitude   Longitude  \
# 0  Monday - Sunday (08:00AM - 10:00PM)  3.120457  101.762861
#
#                                     Waze Link
# 0  https://waze.com/ul?ll=3.120457,101.762861

# %%
#fp_locationlist > div > div.fp_listitem.fp_list_marker86

# %%
'''
<div class="fp_listitem fp_list_marker2" data-latitude="3.128099" data-longitude="101.678678" style="order: 74;">
	<div class="location_left">
		<h4>Subway Menara UOA Bangsar</h4> 
			<div class="infoboxcontent"> 
				<p>Jalan Bangsar Utama 1, Unit 1-2-G, Menara UOA Bangsar, Kuala Lumpur, 59000</p>
				<p></p>
				<p>Monday - Sunday, 8:00 AM - 8:00 PM</p>
				<p></p>
				<p class="infoboxlink"><a href="/find-a-subway" title="Subway Menara UOA Bangsar">Find out more...</a></p> 
			</div> 
			<div class="infopointer">
			</div>
		</div>
		<div class="location_right"> 
			<div class="directionButton">
				<a href="https://goo.gl/maps/8n6W5Syy3vUAGeQV8" target="_blank">
					<i class="fa-solid fa-location-dot"></i>
				</a>
				<a href="https://www.waze.com/en/live-map/directions/my/federal-territory-of-kuala-lumpur/kuala-lumpur/subway-@-menara-uoa-bangsar?place=ChIJPWFRH5RJzDERvHvlO1uTQpY" target="_blank">
					<i class="fa-brands fa-waze"></i>
				</a>
			</div>
		</div>
	</div>
 
<div class="fp_listitem fp_list_marker4" data-latitude="3.152705" data-longitude="101.712034" style="order: 15;">
	<div class="location_left">
 		<h4>Subway Jln Pinang</h4>
   		<div class="infoboxcontent">
     		<p>G9, Wisma UOA II, 19, Jalan Pinang, Kuala Lumpur, 50450</p>
       		<p></p>
         	<p>Monday - Saturday, 8:00 AM – 9:00PM</p>
          	<p>Sunday, 11:30 AM – 6:30PM</p>
           	<p></p>
            <p class="infoboxlink">
            	<a href="/find-a-subway?id=4&amp;view=location" title="Subway Jln Pinang">Find out more...</a>
            </p> 
        </div> 
        <div class="infopointer">
        </div>
    </div>
    <div class="location_right">
    	<div class="directionButton">
    		<a href="https://goo.gl/maps/iLgjQHPoB2Sm9Mcg8" target="_blank">
     			<i class="fa-solid fa-location-dot"></i>
       		</a>
        	<a href="https://www.waze.com/en/live-map/directions/my/wilayah-persekutuan-kuala-lumpur/kuala-lumpur/subway-@-jalan-pinang-kl?place=ChIJIzvym9Q3zDER9MZj809Opn0" target="_blank">
        		<i class="fa-brands fa-waze"></i>
        	</a>
    	</div>
	</div>
</div>

<div class="fp_listitem fp_list_marker19" data-latitude="2.994114" data-longitude="101.758669" style="order: 127;">
	<div class="location_left"> 
 		<h4>Subway Jade Hills</h4>
  		<div class="infoboxcontent"> 
    		<p>No 40-G, Jalan Jade Hills Utama 1/2, Commerce Village, Jade Hills, 43000 Kajang, Selangor. </p>
      		<p class="infoboxlink"> 
        		<a href="/find-a-subway?id=19&amp;view=location" title="Subway Jade Hills">Find out more...</a>
          	</p> 
        </div> 
    	<div class="infopointer">
     	</div>
    </div>
    <div class="location_right"> <div class="directionButton"><a href="https://goo.gl/maps/Y65Ti6Dk5sEbKCeQ9" target="_blank"><i class="fa-solid fa-location-dot"></i></a><a href="https://www.waze.com/en/live-map/directions/my/selangor/kajang/subway-jade-hill?place=ChIJuRzJknvLzTERiX5pZXHT0gw" target="_blank"><i class="fa-brands fa-waze"></i></a></div></div></div>


'''

# %%
import pandas as pd
import time
import os
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from sqlalchemy import create_engine

load_dotenv()

USERNAME = os.getenv("DB_USERNAME")
PASSWORD = os.getenv("DB_PASSWORD")
HOST = os.getenv("DB_HOST")
DATABASE = os.getenv("DB_DATABASE")

URL = "https://subway.com.my/find-a-subway"
LOCATION = "bangi"
SLEEP_TIME = 2

def enterSearchBox(input: str) -> None:
    '''Enter value into search box'''
    
    filter = driver.find_element(By.XPATH, value="/html/body/div[2]/div[2]/div/div/div[2]/div/div/div/div/div/div[1]/div[2]/div[2]/form/div[1]/input")
    filter.send_keys(input)
    filter.send_keys(Keys.ENTER)

def getSoupElements(driver):
    '''Yields scraped web elements containing necessary information using selenium'''
    
    # could be a better way to select elements
    #
    # elements = driver.find_elements(by= By.XPATH, value="//div[@class='fp_listitem fp_list_marker']")
    elements = driver.find_elements(by= By.CSS_SELECTOR, value="div[class^='fp_listitem fp_list_marker']:not(div[style*=' display: none;'])")
    for WebElement in elements:
        elementHTML = WebElement.get_attribute('outerHTML')
        elementSoup = BeautifulSoup(elementHTML,'html.parser')
        yield elementSoup
    pass

def extractData(soupElements) -> list:
    
    data_vector = []
    
    for elements in soupElements:
        
        try:
            location_name = elements.find("h4")
            location_address = elements.select('div.infoboxcontent p')[0]
            operating_hours = elements.select('div.infoboxcontent p')[2]
            waze_link = elements.select('div.directionButton a')[1]['href']
            
            latitude = elements.find("div")['data-latitude']
            longitude = elements.find("div")['data-longitude']
            
            # print(f"Outlet Name: {location_name.text}")
            # print(f"Outlet Address: {location_address.text}")
            # print(f"Operation Hours: {operating_hours.text}")
            # print(f"Latitude: {latitude}")
            # print(f"Longitude: {longitude}")
            # print(f"Waze Link: {waze_link}")
            
            data_list = [location_name.text, location_address.text, operating_hours.text, latitude, longitude, waze_link]

            # data_dict = {
            #     "Outlet Name": [location_name.text],
            #     "Outlet Address": [location_address.text],
            #     "Operation Hours": [operating_hours.text],
            #     "Latitude": [latitude],
            #     "Longitude": [longitude],
            #     "Waze Link": [waze_link] ,
            # }
            
            data_vector.append(data_list)
        except:
            pass
        
    return data_vector

if __name__ == "__main__":
    
    driver = webdriver.Edge()
    driver.get(URL)
        
    try:
        # sleep to let pages load
        time.sleep(SLEEP_TIME)

        enterSearchBox(LOCATION)
        
        # needs to sleep, else selerium scrapes web before filtering location
        time.sleep(SLEEP_TIME)
            
        soupElements = getSoupElements(driver)
        # print(f"Element datatype: {type(webElements)}")
        
        data = extractData(soupElements)
        # print(data)
        
        df = pd.DataFrame(data, columns=['Outlet Name', 'Outlet Address', 'Operating Hours', 'Latitude', 'Longitude', 'Waze Link'])
        
        df = df.astype(dtype= {
            'Latitude': 'float64', 
            'Longitude': 'float64', 
        })
        
        conn = f'postgresql://{USERNAME}:{PASSWORD}@{HOST}/{DATABASE}?sslmode=require'
        # engine = create_engine(f'postgresql://root:root@localhost:5432/subway_outlet')
        engine = create_engine(conn)
        
        
        # file_name = f"web_{LOCATION}.csv"
        # df.to_csv(file_name)
        
        df.to_sql('kl_outlet', engine, if_exists='replace')
        
    except Exception as e:
        print(f"There is an exception: {e}")
        
    finally:
        # terminates web driver
        driver.quit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 13
#       9 from sqlalchemy import create_engine
#      11 load_dotenv()
# ---> 13 USERNAME = os.getenv["DB_USERNAME"]
#      14 PASSWORD = os.getenv["DB_PASSWORD"]
#      15 HOST = os.getenv["DB_HOST"]
#
# TypeError: 'function' object is not subscriptable
